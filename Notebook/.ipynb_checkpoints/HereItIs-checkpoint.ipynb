# %% [markdown]
# ## This is the basic load and clean stuff

# %%
import pandas as pd
import numpy as np
import datetime as datetime
import pandas.api.types as pt


input_dir = '/mnt/d/DivvyDatasets'
input_divvy = input_dir + "/" + "divvy_trip_history_201909-202108.csv"
input_chitemp = input_dir + "/" + "ChicagoTemperature.csv"


def yrmo(year, month):
    return "{}-{}".format(year, month)


def calc_duration_in_minutes(started_at, ended_at):
    st = datetime.datetime.strptime(started_at, '%Y-%m-%d %H:%M:%S')
    en = datetime.datetime.strptime(ended_at, '%Y-%m-%d %H:%M:%S')
    diff = en - st
    return diff.total_seconds() / 60

#
# load the divvy csv into a data frame
#
print("Loading " + input_divvy)
# so need to set the type on a couple of columns
col_names = pd.read_csv(input_divvy, nrows=0).columns
types_dict = { 'ride_id': str, 
  'start_station_id': str,
  'end_station_id': str}
types_dict.update({col: str for col in col_names if col not in types_dict})
df_divvy = pd.read_csv(input_divvy, dtype=types_dict)
print(df_divvy)


#
# load the chicago temperature into a data frame
#
print("Loading " + input_chitemp)
df_chitemp = pd.read_csv(input_chitemp)
print(df_chitemp)


#
# add a year-month column to the divvy dataframe
#  this uses a function with the row; it is not
#  the absolute fastest way
#
print("Adding year-month as yrmo")
df_divvy['yrmo'] = df_divvy.apply(lambda row: yrmo(row['year'], row['month']),
                                    axis = 1)



#
# we also want a duration to be calculated
#
print("Adding duration")
df_divvy['duration'] = df_divvy.apply(lambda row: calc_duration_in_minutes(row['started_at'],
                                                    row['ended_at']),
                                    axis = 1)


#
# btw, can just pass the row and let the function figure it out
#
#def procone(row):
#    print(row['date'])
#    return 0
#df_divvy.apply(lambda row: procone(row), axis = 1)



#
# add the temperature
#
print("Merging in temperature")
df_divvy = pd.merge(df_divvy, df_chitemp,
  on="date")
print(df_divvy.shape)
print(df_divvy.head())
print(df_divvy.loc[df_divvy['date'] == '2020-02-21'])

print(df_divvy.info())  # shows mem usage, other info
print(df_divvy[['ride_id','member_casual','date','duration','yrmo','avg_temperature_fahrenheit']])


#
# clean the dataframe to remove invalid durations
#   which are really only (about) < 1 minute, or > 12 hours
#
print("Removing invalid durations")
df_divvy = df_divvy[(df_divvy.duration >= 1.2) & (df_divvy.duration < 60 * 12)]
print(df_divvy.shape)

#
# we need to get the dow properly set
#
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

cats_type = pt.CategoricalDtype(categories=cats, ordered=True)
df_divvy['day_of_week'] = df_divvy['day_of_week'].astype(cats_type)
# Out:
# Loading /mnt/d/DivvyDatasets/divvy_trip_history_201909-202108.csv
#         Unnamed: 0       ID     ...1           ride_id rideable_type  \
# 0                1  1147482  8267501          24710636   docked_bike
# 1                2  1147483  8267502          24710637   docked_bike
# 2                3  1147484  8267503          24710638   docked_bike
# 3                4  1147485  8267504          24710639   docked_bike
# 4                5  1147486  8267505          24710640   docked_bike
# ...            ...      ...      ...               ...           ...
# 8317275   -87.6355        member  2021-08-31    08  31  2021     Tuesday
# 8317276   -87.6346        casual  2021-08-31    08  31  2021     Tuesday
# 8317277  -87.65862        member  2021-08-31    08  31  2021     Tuesday
# 8317278   -87.6346        member  2021-08-31    08  31  2021     Tuesday
# 8317279   -87.6346        member  2021-08-31    08  31  2021     Tuesday
#
# [8317280 rows x 21 columns]
# Loading /mnt/d/DivvyDatasets/ChicagoTemperature.csv
#            date  avg_temperature_celsius  avg_temperature_fahrenheit  \
# 0    2019-09-01                     19.1                        66.3
# 1    2019-09-02                     22.2                        72.0
# 2    2019-09-03                     23.7                        74.7
# 3    2019-09-04                     18.5                        65.3
# 4    2019-09-05                     18.2                        64.7
# ..          ...                      ...                         ...
# 726  2021-08-27                     26.6                        80.0
# 727  2021-08-28                     29.2                        84.5
# 728  2021-08-29                     27.9                        82.3
# 729  2021-08-30                     24.2                        75.6
# 730  2021-08-31                     23.7                        74.6
#
#     avg_humidity  avg_rain_intensity_mm/hour  avg_wind_speed  max_wind_speed  \
# 0            82%                         1.0             1.4             8.9
# 1            74%                         0.0             1.4             5.4
# 2            74%                         0.3             2.9            16.1
# 3            71%                         0.0             2.4             8.1
# 4            68%                         0.0             1.6             5.2
# ..           ...                         ...             ...             ...
# 726          76%                         0.0             2.1             6.6
# 727          67%                         0.0             2.5             9.1
# 728          68%                         0.0             2.6            12.3
# 729          65%                         0.0             2.2             5.4
# 730          65%                         0.0             2.7             9.5
#
#      total_solar_radiation  Unnamed: 8
# 0                     4351         NaN
# 1                     9517         NaN
# 2                     3281         NaN
# 3                     9734         NaN
# 4                     8574         NaN
# ..                     ...         ...
# 726                  14958         NaN
# 727                  15381         NaN
# 728                  13563         NaN
# 729                  16349         NaN
# 730                  13771         NaN
#
# [731 rows x 9 columns]
# Adding year-month as yrmo
# Adding duration
# Merging in temperature
# (8317280, 31)
#   Unnamed: 0       ID     ...1   ride_id rideable_type           started_at  \
# 0          1  1147482  8267501  24710636   docked_bike  2019-09-01 00:00:15
# 1          2  1147483  8267502  24710637   docked_bike  2019-09-01 00:00:48
# 2          3  1147484  8267503  24710638   docked_bike  2019-09-01 00:01:13
# 3          4  1147485  8267504  24710639   docked_bike  2019-09-01 00:01:34
# 4          5  1147486  8267505  24710640   docked_bike  2019-09-01 00:03:29
#
#               ended_at            start_station_name start_station_id  \
# 0  2019-09-01 00:05:00  Southport Ave & Waveland Ave              227
# 1  2019-09-01 00:06:46         Wells St & Concord Ln              289
# 2  2019-09-01 00:07:53       Broadway & Waveland Ave              304
# 3  2019-09-01 00:11:04         Wells St & Concord Ln              289
# 4  2019-09-01 00:21:53         Wells St & Concord Ln              289
#
#                  end_station_name  ...     yrmo   duration  \
# 0  Ashland Ave & Belle Plaine Ave  ...  2019-09   4.750000
# 1437003                      Millennium Park               90
#
#                       end_station_name  ...     yrmo   duration  \
# 1431495  Greenview Ave & Fullerton Ave  ...  2020-02  15.166667
# 1431496           Clinton St & Polk St  ...  2020-02   4.116667
# 1431497          Canal St & Madison St  ...  2020-02   6.933333
# 1431498       Wells St & Evergreen Ave  ...  2020-02   9.316667
# 1431499          Millard Ave & 26th St  ...  2020-02  50.600000
# ...                                ...  ...      ...        ...
# 1436999     Indiana Ave & Roosevelt Rd  ...  2020-02  10.100000
# 1437000      Franklin St & Chicago Ave  ...  2020-02   7.200000
# 1437001       Kingsbury St & Kinzie St  ...  2020-02   8.416667
# 1437002   Clinton St & Washington Blvd  ...  2020-02  13.750000
# 1437003       McClurg Ct & Illinois St  ...  2020-02   9.066667
#
#         avg_temperature_celsius avg_temperature_fahrenheit avg_humidity  \
# 1431495                    -0.3                       31.4          58%
# 1431496                    -0.3                       31.4          58%
# 1431497                    -0.3                       31.4          58%
# 1431498                    -0.3                       31.4          58%
# 1431499                    -0.3                       31.4          58%
# ...                         ...                        ...          ...
# 1436999                    -0.3                       31.4          58%
# 1437000                    -0.3                       31.4          58%
# 1437001                    -0.3                       31.4          58%
# 1437002                    -0.3                       31.4          58%
# 1437003                    -0.3                       31.4          58%
#
#         avg_rain_intensity_mm/hour avg_wind_speed max_wind_speed  \
# 1431495                        0.0            3.6           11.9
# 1431496                        0.0            3.6           11.9
# 1431497                        0.0            3.6           11.9
# 1431498                        0.0            3.6           11.9
# 1431499                        0.0            3.6           11.9
# ...                            ...            ...            ...
# 1436999                        0.0            3.6           11.9
# 1437000                        0.0            3.6           11.9
# 1437001                        0.0            3.6           11.9
# 1437002                        0.0            3.6           11.9
# 1437003                        0.0            3.6           11.9
#
#         total_solar_radiation Unnamed: 8
# 1431495                  2995        NaN
# 1431496                  2995        NaN
# 1431497                  2995        NaN
# 1431498                  2995        NaN
# 1431499                  2995        NaN
# ...                       ...        ...
# 1436999                  2995        NaN
# 1437000                  2995        NaN
# 1437001                  2995        NaN
# 1437002                  2995        NaN
# 1437003                  2995        NaN
#
# [5509 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8317280 entries, 0 to 8317279
# Data columns (total 31 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Unnamed: 0                  object
#  1   ID                          object
#  2   ...1                        object
#  3   ride_id                     object
#  4   rideable_type               object
#  5   started_at                  object
#  6   ended_at                    object
#  7   start_station_name          object
#  8   start_station_id            object
#  9   end_station_name            object
#  10  end_station_id              object
#  11  start_lat                   object
#  12  start_lng                   object
#  13  end_lat                     object
#  14  end_lng                     object
#  15  member_casual               object
#  16  date                        object
#  17  month                       object
#  18  day                         object
#  19  year                        object
#  20  day_of_week                 object
#  21  yrmo                        object
#  22  duration                    float64
#  23  avg_temperature_celsius     float64
#  24  avg_temperature_fahrenheit  float64
#  25  avg_humidity                object
#  26  avg_rain_intensity_mm/hour  float64
#  27  avg_wind_speed              float64
#  28  max_wind_speed              float64
#  29  total_solar_radiation       int64
#  30  Unnamed: 8                  float64
# dtypes: float64(7), int64(1), object(23)
# memory usage: 2.0+ GB
# None
#                   ride_id member_casual        date   duration     yrmo  \
# 0                24710636        member  2019-09-01   4.750000  2019-09
# 1                24710637        member  2019-09-01   5.966667  2019-09
# 2                24710638        member  2019-09-01   6.666667  2019-09
# 3                24710639        member  2019-09-01   9.500000  2019-09
# 4                24710640        member  2019-09-01  18.400000  2019-09
# ...                   ...           ...         ...        ...      ...
# 8317275  98EAC61BBAAF73C9        member  2021-08-31   7.583333  2021-08
# 8317276  B060D2DF6AC0D65B        casual  2021-08-31  11.533333  2021-08
# 8317277  D22E7B3E5C0D162E        member  2021-08-31  18.150000  2021-08
# 8317278  4C86FE37842CD185        member  2021-08-31   7.950000  2021-08
# 8317279  6BEE9ACBA8E9BD51        member  2021-08-31   5.516667  2021-08
#
#          avg_temperature_fahrenheit
# 0                              66.3
# 1                              66.3
# 2                              66.3
# 3                              66.3
# 4                              66.3
# ...                             ...
# 8317275                        74.6
# 8317276                        74.6
# 8317277                        74.6
# 8317278                        74.6
# 8317279                        74.6
#
# [8317280 rows x 6 columns]
# Removing invalid durations
# (8190307, 31)

# %% [markdown]
# ## Look at the average duration by rider type & day of week
# ### average duration by day of week for rider types

# %%
df_rider_by_dow = df_divvy.groupby(['member_casual','day_of_week']).agg(mean_time = ('duration', 'mean')).round(2)
df_rider_by_dow

df_rider_by_dow.sort_values(by=['member_casual','day_of_week'])
# Out:
#                            mean_time
# member_casual day_of_week
# casual        Monday           31.34
#               Tuesday          28.65
#               Wednesday        28.07
#               Thursday         27.94
#               Friday           29.24
#               Saturday         33.72
#               Sunday           35.30
# member        Monday           13.46
#               Tuesday          13.32
#               Wednesday        13.40
#               Thursday         13.38
#               Friday           13.73
#               Saturday         15.98
#               Sunday           16.14

# %% [markdown]
# ### Now we want to plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### bar plot

# %%
df_rider_by_dow.unstack('member_casual').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='day_of_week'>

# %% [markdown]
# ## Look at the number of riders by type and day of week
# ### grouping

# %%
df_rider_by_dow = df_divvy.groupby(['member_casual','day_of_week']).agg(num_rides = ('ID', 'count'))
df_rider_by_dow

#df_rider_by_dow['day_of_week'] = df_rider_by_dow['day_of_week'].astype(cats_type)
df_rider_by_dow.sort_values(by=['member_casual','day_of_week'])
# Out:
#                            num_rides
# member_casual day_of_week
# casual        Monday          368155
#               Tuesday         347995
#               Wednesday       350736
#               Thursday        371177
#               Friday          467382
#               Saturday        734235
#               Sunday          628519
# member        Monday          706423
#               Tuesday         753748
#               Wednesday       749612
#               Thursday        742154
#               Friday          727633
#               Saturday        658274
#               Sunday          584264

# %% [markdown]
# ### plot

# %%
df_rider_by_dow.unstack('member_casual').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='day_of_week'>
